# %%
#!% pip install

# %%
import base64
import anthropic
import os
import dotenv

# %%
dotenv.load_dotenv()

API_KEY = "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"
# API_KEY = os.getenv("ANTHROPIC_API_KEY")
client = anthropic.Anthropic(api_key=API_KEY)

# %%
IMAGE_PATH = "/Users/ZapXDragon/Desktop/zap/LaTrobeUni/CAP/CV-Accessibility-of-Public-Transport/backend/app/claude_test/accessibility_feature.jpg"
MESSAGE = "Identify the main accessibility feature in this image."

# %%
def encode_image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        encoded_string = base64.b64encode(image_file.read()).decode("utf-8")
    return encoded_string

# %%
base64_image = encode_image_to_base64(IMAGE_PATH)

# %%
response = client.messages.create(
    max_tokens=1000,
    messages=[
        {"role": "user",
         "content": [
             {"type": "image", "source": {
                 "type": "base64",
                 "media_type": "image/jpeg",
                 "data": base64_image
             }},
             {"type": "text", "text": MESSAGE}
             
         ]}],
    model="claude-opus-4-6"
)

# %%
# response = client.messages.create(
#     max_tokens=100,
#     messages=[
#         {"role": "user", "content": MESSAGE}
#     ],
#     model="claude-opus-4-6",
# )

# %%
print (response.content[0].text)
# Out:
# # Tactile Ground Surface Indicators (TGSIs)
#
# The main accessibility feature shown is **tactile paving** (also known as **detectable warning surfaces** or **tactile walking surface indicators**), designed to assist **visually impaired or blind pedestrians**.
#
# Two distinct patterns are visible:
#
# - **Elongated bars/strips** — These are **directional indicators** (guide strips) that indicate the safe path of travel to follow.
# - **Raised dome/dot patterns** — These are **warning indicators** that signal a decision point, hazard, or change in direction.
#
# These textured ground surfaces can be detected underfoot or with a **white cane**, helping visually impaired individuals navigate public spaces like transit stations, sidewalks, and building entrances safely and independently.
#
# The sign reading "**Higher Education Institute**" suggests this is located in a public or institutional building, likely a transit station or campus.
